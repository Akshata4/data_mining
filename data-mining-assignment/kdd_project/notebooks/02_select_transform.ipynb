# %% [markdown]
# # KDD Stage 2 — Selection / Preprocessing / Transformation
#
# Operate on TRAIN only to avoid leakage; basic drift checks & multicollinearity intuition.

# %% [markdown]
# **Intuition plots (TRAIN+VAL):**
#
# ![](assets/stage2_scatter_petal.png)
#
# ![](assets/stage2_scatter_sepal.png)

# %% [markdown]
# **Drift snapshot (TRAIN→VAL and TRAIN→TEST)**
#
# | feature       |   KS_D |   KS_p |    SMD |
# |:--------------|-------:|-------:|-------:|
# | SepalLengthCm |  0.153 |  0.637 | -0.04  |
# | SepalWidthCm  |  0.152 |  0.647 | -0.233 |
# | PetalLengthCm |  0.085 |  0.995 |  0.08  |
# | PetalWidthCm  |  0.131 |  0.811 | -0.072 |
#
# | feature       |   KS_D |   KS_p |    SMD |
# |:--------------|-------:|-------:|-------:|
# | SepalLengthCm |  0.166 |  0.535 | -0.142 |
# | SepalWidthCm  |  0.211 |  0.24  | -0.351 |
# | PetalLengthCm |  0.094 |  0.984 |  0.032 |
# | PetalWidthCm  |  0.074 |  1     |  0.001 |

# %%
# (Optional) recompute drift tables
# Provided for reproducibility; results pre-rendered above.
