# %% [markdown]
# # KDD Stage 4 — Evaluation / Interpretation
#
# Strict TEST-only evaluation; no tuning here.

# %% [markdown]
# **Metrics (TEST):**
# - Accuracy: **0.967**
# - Macro-F1: **0.967**
# - Macro AUC (OvR): **0.998**
# - Micro AUC (OvR): **0.999**

# %% [markdown]
# **Confusion Matrix (counts):**
#
# ![](assets/stage4_confusion.png)

# %% [markdown]
# **ROC Curves (one-vs-rest):**
#
# ![](assets/stage4_roc_Iris-setosa.png)
# ![](assets/stage4_roc_Iris-versicolor.png)
# ![](assets/stage4_roc_Iris-virginica.png)

# %% [markdown]
# **Permutation Importance (VALIDATION):**
#
# ![](assets/stage4_perm_val.png)

# %% [markdown]
# **Reliability (calibration) curves by class:**
#
# ![](assets/stage4_reliability_Iris-setosa.png)
# ![](assets/stage4_reliability_Iris-versicolor.png)
# ![](assets/stage4_reliability_Iris-virginica.png)

# %%
# Cells to regenerate figures are omitted for brevity (already attached above).
# See Stage 4 scripts for full evaluation code.
