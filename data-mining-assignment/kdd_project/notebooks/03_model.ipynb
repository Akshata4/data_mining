# %% [markdown]
# # KDD Stage 3 — Modeling
#
# Pipelines + lean grids; repeated stratified CV (5×2), scoring macro-F1.

# %% [markdown]
# **Leaderboard (CV on TRAIN+VAL):**
#
# | model         |   cv_mean_f1_macro | best_params                                                                                                 |
# |:--------------|-------------------:|:------------------------------------------------------------------------------------------------------------|
# | knn           |             0.9743 | {'clf__n_neighbors': 7, 'clf__weights': 'uniform'}                                                          |
# | logreg_kbest2 |             0.97   | {'clf__C': 0.1}                                                                                             |
# | logreg        |             0.9613 | {'clf__C': 10}                                                                                              |
# | svc_rbf       |             0.9613 | {'clf__C': 1, 'clf__gamma': 0.1}                                                                            |
# | rf            |             0.9572 | {'clf__max_depth': None, 'clf__max_features': 'sqrt', 'clf__min_samples_leaf': 2, 'clf__n_estimators': 100} |
# | tree          |             0.9488 | {'clf__criterion': 'gini', 'clf__max_depth': None, 'clf__min_samples_leaf': 2}                              |

# %% [markdown]
# **Winner:** `knn`
# **Best params:** `{'clf__n_neighbors': 7, 'clf__weights': 'uniform'}`

# %%
# Code to re-run the modeling inside the notebook (lean grids for speed) is provided here:
# (omitted to keep file light; see scripts in the zip package for full detail)
